# %% [markdown]
# # Duckify
#
# This notebook orchestrates the whole pipeline allowing step by step execution

# %%
import os
from pathlib import Path

from dotenv import load_dotenv

from genai.client import GenAIClient
from tracing.color import Color
from tracing.config import TracerConfig
from tracing.tracer import Tracer

# %%
PROJECT_DIR = Path(".")
ASSETS_DIR = PROJECT_DIR / "assets"
OUTPUT_DIR = PROJECT_DIR / "output"

# %%
texture_path: Path = ASSETS_DIR / "textures" / "trapezoid_colors.png"
model_path: Path = ASSETS_DIR / "models" / "trapezoid_letters.obj"

texture_name: str = texture_path.stem
model_name: str = model_path.stem
trace_output_path: Path = OUTPUT_DIR / f"{model_name}-{texture_name}-trace.json"

palette: tuple[Color, ...] = ((255, 255, 255), (255, 0, 0), (0, 255, 0))

# %% [markdown]
# ## 1. Texture Generation

# %%
import os
from pathlib import Path
from dotenv import load_dotenv

glb_path = ASSETS_DIR / "models" / "official_model_1.glb"

load_dotenv("genai/.env")
SSH_HOST = os.getenv("SSH_HOST", "")
SSH_USER = os.getenv("SSH_USER", "")
SSH_KEY_PATH = Path.home() / ".ssh" / "wireguard_key"
HF_TOKEN = os.getenv("HF_TOKEN", "")

STEPS = 30
GUIDANCE = 6

NEGATIVE_PROMPT = "complex, realistic, sketchy, hatching,shiny, thin lines, blurry, deformed, gradients, photorealistic"
PROMPT_WRAPPER=""
PROMPT = "a superman duck"

client = GenAIClient(ssh_host=SSH_HOST, ssh_user=SSH_USER, ssh_key_path=SSH_KEY_PATH, hf_token=HF_TOKEN,remote_port=5002)

result = client.generate(output_dir=OUTPUT_DIR,obj_path=glb_path, steps=STEPS, guidance=GUIDANCE, negative_prompt=NEGATIVE_PROMPT, prompt_wrapper=PROMPT_WRAPPER, prompt=PROMPT)

print(result)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[6], line 22
#      18 PROMPT = "a superman duck"
#      20 client = GenAIClient(ssh_host=SSH_HOST, ssh_user=SSH_USER, ssh_key_path=SSH_KEY_PATH, hf_token=HF_TOKEN,remote_port=5002)
# ---> 22 result = client.generate(output_dir=OUTPUT_DIR,obj_path=glb_path, steps=STEPS, guidance=GUIDANCE, negative_prompt=NEGATIVE_PROMPT, prompt_wrapper=PROMPT_WRAPPER, prompt=PROMPT)
#      24 print(result)
#
# File ~/Music/Duckify/genai/client.py:70, in GenAIClient.generate(self, obj_path, prompt, output_dir, negative_prompt, prompt_wrapper, steps, guidance)
#      59 def generate(
#      60     self,
#      61     obj_path: Path,
#    (...)     67     guidance: float = 6.0,
#      68 ) -> tuple[Optional[Path], Optional[str]]:
#      69     output_dir = output_dir.resolve()
# ---> 70     with self.open_tunnel() as tunnel:
#      71         if tunnel is None:
#      72             err = "Error while opening SSH tunnel"
#
# File ~/Music/Duckify/genai/client.py:36, in GenAIClient.open_tunnel(self)
#      35 def open_tunnel(self) -> SSHTunnelForwarder:
# ---> 36     return SSHTunnelForwarder(
#      37         (self.ssh_host, self.ssh_port),
#      38         ssh_username=self.ssh_user,
#      39         ssh_pkey=self.ssh_key_path,
#      40         remote_bind_address=(self.remote_host, str(self.remote_port)),
#      41     )
#
# File ~/Music/Duckify/.venv/lib/python3.11/site-packages/sshtunnel.py:941, in SSHTunnelForwarder.__init__(self, ssh_address_or_host, ssh_config_file, ssh_host_key, ssh_password, ssh_pkey, ssh_private_key_password, ssh_proxy, ssh_proxy_enabled, ssh_username, local_bind_address, local_bind_addresses, logger, mute_exceptions, remote_bind_address, remote_bind_addresses, set_keepalive, threaded, compression, allow_agent, host_pkey_directories, *args, **kwargs)
#     938     raise ValueError('Unknown arguments: {0}'.format(kwargs))
#     940 # remote binds
# --> 941 self._remote_binds = self._get_binds(remote_bind_address,
#     942                                      remote_bind_addresses,
#     943                                      is_remote=True)
#     944 # local binds
#     945 self._local_binds = self._get_binds(local_bind_address,
#     946                                     local_bind_addresses)
#
# File ~/Music/Duckify/.venv/lib/python3.11/site-packages/sshtunnel.py:1254, in SSHTunnelForwarder._get_binds(bind_address, bind_addresses, is_remote)
#    1252         if isinstance(local_bind, tuple) and len(local_bind) == 1:
#    1253             bind_addresses[i] = (local_bind[0], 0)
# -> 1254 check_addresses(bind_addresses, is_remote)
#    1255 return bind_addresses
#
# File ~/Music/Duckify/.venv/lib/python3.11/site-packages/sshtunnel.py:155, in check_addresses(address_list, is_remote)
#     151     raise AssertionError('UNIX domain sockets not allowed for remote'
#     152                          'addresses')
#     154 for address in address_list:
# --> 155     check_address(address)
#
# File ~/Music/Duckify/.venv/lib/python3.11/site-packages/sshtunnel.py:110, in check_address(address)
#     108 if isinstance(address, tuple):
#     109     check_host(address[0])
# --> 110     check_port(address[1])
#     111 elif isinstance(address, string_types):
#     112     if os.name != 'posix':
#
# File ~/Music/Duckify/.venv/lib/python3.11/site-packages/sshtunnel.py:85, in check_port(port)
#      84 def check_port(port):
# ---> 85     assert isinstance(port, int), 'PORT is not a number'
#      86     assert port >= 0, 'PORT < 0 ({0})'.format(port)
#
# AssertionError: PORT is not a number

# %% [markdown]
# ## 2. Path Tracing

# %%
tracer_config: TracerConfig = TracerConfig()
tracer: Tracer = Tracer(
    tracer_config,
    texture_path,
    model_path,
    palette,
)
tracer.compute_traces()
tracer.export_traces(trace_output_path)

# %% [markdown]
# ## 3. Robot Drawing

# %%
# TODO
